# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pickle
from tqdm import tqdm

# %%
with open('data.pkl', 'rb') as f:
    data = pickle.load(f)

print(type(data))
print(data.shape)
# Out:
# <class 'numpy.ndarray'>
# (506, 6)

# %%
batch_size = 30

# %%
quotient, remainder = np.divmod(data.shape[0], batch_size)
print(quotient, remainder)
# Out:
# 16 26

# %%
idx_batches = list()
for idx in range(0, np.multiply((quotient - 1), batch_size) , batch_size):
    
    idx_batches.append((idx, idx + batch_size))

idx_batches.append((np.multiply((quotient - 1), batch_size), data.shape[0]))
idx_batches[:5]
# Out:
# [(0, 30), (30, 60), (60, 90), (90, 120), (120, 150)]

# %%
for lower_limit, upper_limit in idx_batches:
    
    idxes = np.arange(lower_limit, upper_limit)
# Out:
# (30,)
# (30,)
# (30,)
# (30,)
# (30,)
# (30,)
# (30,)
# (30,)
# (30,)
# (30,)
# (30,)
# (30,)
# (30,)
# (30,)
# (30,)
# (56,)
